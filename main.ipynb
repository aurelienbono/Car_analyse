# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("data/KaggleCarData.csv")

# %%
df.head(20)
# Out:
#                 Car_Name  Year  Present_Price  Kms_Driven Fuel_Type  \
# 0     Hero Passion X pro  2016      12417.550       33217    Petrol
# 1                  xcent  2017      10633.130       12905    Petrol
# 2                  verna  2015      10881.400       62053    Diesel
# 3                 ertiga  2016      11107.790       43897    Diesel
# 4                   jazz  2016      10316.400        4108    Petrol
# 5   Honda CB Hornet 160R  2017      11310.870        4110    Petrol
# 6          Honda CBR 150  2014       9610.200       24909    Petrol
# 7          KTM 390 Duke   2014      10356.400        9154    Petrol
# 8                    sx4  2011       9683.010       51475    Petrol
# 9          vitara brezza  2018      11082.830        2944    Diesel
# 10               etios g  2014       9480.800       40759    Petrol
# 11                 verna  2017      12199.400       16991    Petrol
# 12                  city  2014       9984.000       64770    Diesel
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# Car_Name         0.0
# Year             0.0
# Present_Price    0.0
# Kms_Driven       0.0
# Fuel_Type        0.0
# Seller_Type      0.0
# Transmission     0.0
# Owner            0.0
# Selling_Price    0.0
# dtype: float64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['Year'] , data=df , orient="90" )
plt.title("Le Nombre de voiture par année ")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['Fuel_Type']) 
plt.title("Le nombre de voiture en function du type de carburant ") 
plt.show()

# %%
plt.figure(figsize=(9,5)) 
sns.countplot(x=df['Seller_Type'] , palette='crest')
plt.title("Nombre de voiture en fonction du type de  vendeur ")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['Transmission'])
plt.title("Nombre total de voiture en fonction de le transmission ")
plt.show()

# %%
df.groupby(['Year'])['Selling_Price'].sum()
# Out:
# Year
# 2003    9.298642e+05
# 2004    3.989391e+06
# 2005    4.544321e+06
# 2006    4.233455e+06
# 2007    1.877701e+06
# 2008    1.197690e+07
# 2009    9.917084e+06
# 2010    2.515216e+07
# 2011    4.814719e+07
# 2012    5.808000e+07
# 2013    8.373877e+07
# 2014    9.629614e+07
# 2015    2.314894e+08
# 2016    1.911257e+08
# 2017    1.310841e+08
# 2018    3.631785e+06
# Name: Selling_Price, dtype: float64

# %%
df.groupby(['Year'])['Present_Price'].sum().plot(figsize=(20,10) , marker="x", linestyle="--")
plt.ylabel("Present_Price")
plt.title("Volume de vente de vehicule en fonction des année")
plt.show()

# %%
plt.figure(figsize=(20,10))
df.groupby('Seller_Type')['Kms_Driven'].value_counts(ascending=True).plot()
plt.show()

# %%
df.groupby('Year')['Present_Price','Selling_Price'].sum().plot.barh(color=sns.color_palette('Set1'), figsize=(20,10))
plt.title("Les annees en fonction present price et du  selleing price ")
plt.xlabel("price")
plt.show()
# Out:
# /var/folders/8q/8d782ynj03g_qfjq1ptf4v1w0000gn/T/ipykernel_11905/3412669246.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
df.groupby('Seller_Type')['Fuel_Type'].value_counts(ascending=True).plot(kind='barh', color=sns.color_palette('Paired'), figsize=(12,10)) 
plt.xlabel("Car_count")
# Out:
# Text(0.5, 0, 'Car_count')

# %%
df.groupby('Fuel_Type')['Present_Price'].sum().plot(kind='pie',figsize=(8,10), autopct="%f%%",)
plt.title("Fuel_Type en fonction des Present_Price")
# Out:
# Text(0.5, 1.0, 'Fuel_Type en fonction des Present_Price')

# %%
df.groupby('Seller_Type')['Transmission'].count().plot(kind='pie',autopct='%f%%',figsize=(8,10))
plt.title("Seller_Type en fonction des Transmission")
# Out:
# Text(0.5, 1.0, 'Seller_Type en fonction des Transmission')

# %%
df.head(10)
# Out:
#                Car_Name  Year  Present_Price  Kms_Driven Fuel_Type  \
# 0    Hero Passion X pro  2016       12417.55       33217    Petrol
# 1                 xcent  2017       10633.13       12905    Petrol
# 2                 verna  2015       10881.40       62053    Diesel
# 3                ertiga  2016       11107.79       43897    Diesel
# 4                  jazz  2016       10316.40        4108    Petrol
# 5  Honda CB Hornet 160R  2017       11310.87        4110    Petrol
# 6         Honda CBR 150  2014        9610.20       24909    Petrol
# 7         KTM 390 Duke   2014       10356.40        9154    Petrol
# 8                   sx4  2011        9683.01       51475    Petrol
# 9         vitara brezza  2018       11082.83        2944    Diesel
#
#   Seller_Type Transmission  Owner  Selling_Price
# 0  Individual       Manual      0       11717.50
# 1      Dealer       Manual      0        9931.75
# 2      Dealer       Manual      0       10180.25
# ...

# %%
df.groupby(['Year','Fuel_Type'])['Transmission'].count().plot(kind='bar',figsize=(20,10))
plt.title("Les annees et Fuel_Type en fonction de la transmission  ")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(x=df['Present_Price'])
# Out:
# <AxesSubplot:xlabel='Present_Price', ylabel='Count'>

# %%
df.head()
# Out:
#              Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  Hero Passion X pro  2016       12417.55       33217    Petrol  Individual
# 1               xcent  2017       10633.13       12905    Petrol      Dealer
# 2               verna  2015       10881.40       62053    Diesel      Dealer
# 3              ertiga  2016       11107.79       43897    Diesel      Dealer
# 4                jazz  2016       10316.40        4108    Petrol      Dealer
#
#   Transmission  Owner  Selling_Price
# 0       Manual      0       11717.50
# 1       Manual      0        9931.75
# 2       Manual      0       10180.25
# 3       Manual      0       10404.75
# 4       Manual      0        9614.00

# %%
sns.pairplot(vars = ['Fuel_Type','Seller_Type',],data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Selling_Price'],
#       dtype='object')

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3])

# %%
df.groupby('Owner')['Seller_Type'].value_counts().plot.barh(color =sns.color_palette("cividis_r"),figsize=(20,10))
plt.title("Owner,Seller_Type by  car number")
plt.show()

# %%
df.head()
# Out:
#              Car_Name  Year  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  Hero Passion X pro  2016       12417.55       33217    Petrol  Individual
# 1               xcent  2017       10633.13       12905    Petrol      Dealer
# 2               verna  2015       10881.40       62053    Diesel      Dealer
# 3              ertiga  2016       11107.79       43897    Diesel      Dealer
# 4                jazz  2016       10316.40        4108    Petrol      Dealer
#
#   Transmission  Owner  Selling_Price
# 0       Manual      0       11717.50
# 1       Manual      0        9931.75
# 2       Manual      0       10180.25
# 3       Manual      0       10404.75
# 4       Manual      0        9614.00

# %%
import plotly.express as px 

fig = px.scatter(df , x='Year' , y= 'Selling_Price', color='Transmission' )
fig

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Selling_Price'],
#       dtype='object')

# %%
df.drop(columns=['Car_Name', 'Present_Price'] , inplace=True)
df.head()
# Out:
#    Year  Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Selling_Price
# 0  2016       33217    Petrol  Individual       Manual      0       11717.50
# 1  2017       12905    Petrol      Dealer       Manual      0        9931.75
# 2  2015       62053    Diesel      Dealer       Manual      0       10180.25
# 3  2016       43897    Diesel      Dealer       Manual      0       10404.75
# 4  2016        4108    Petrol      Dealer       Manual      0        9614.00

# %%
string_col = ['Fuel_Type' , 'Seller_Type','Transmission'] 

i = 0 
for i in string_col : 
    df[i] = df['i'].astype('category').cat.codes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'i'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
